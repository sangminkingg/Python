# %%
# train : 2000장 
# val : 1000장
# test : 22장

# %%
# 데이터 경로 지정
train_dir = '/content/drive/MyDrive/Colab Notebooks/사물지능_딥러닝_2022/dogs_vs_cats_small/train'
val_dir = '/content/drive/MyDrive/Colab Notebooks/사물지능_딥러닝_2022/dogs_vs_cats_small/validation'
test_dir = '/content/drive/MyDrive/Colab Notebooks/사물지능_딥러닝_2022/dogs_vs_cats_small/test'

# %%
import os
print(len(os.listdir(train_dir)))
print(len(os.listdir(val_dir)))
print(len(os.listdir(test_dir)))
# Out:
# 2
# 2
# 2

# %%
# 하나의 변수에 이미지파일 전부 다 합치기
# 픽셀값 0~255 > 0~1
# 이미지 크기 동일하게 만들어주기 (150,150)
# 라벨링
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 픽셀값 변환
train_gen = ImageDataGenerator(rescale=1./255)
test_gen = ImageDataGenerator(rescale=1./255)
val_gen = ImageDataGenerator(rescale=1./255)

# %%
# flow_from_directory()
train_generator = train_gen.flow_from_directory(
    train_dir, # train 이미지경로
    target_size = (150, 150), # 변환할 이미지의 크기
    batch_size = 100, # 한번에 변환할 이미지 갯수
    class_mode = 'binary' # 라벨링 진행, catergorical : 다중분류
    # 폴더별로 라벨링을 진행 cats(0), dogs(1)
    )
# Out:
# Found 2000 images belonging to 2 classes.

# %%
test_generator = test_gen.flow_from_directory(
    test_dir, # train 이미지경로
    target_size = (150, 150), # 변환할 이미지의 크기
    batch_size = 100, # 한번에 변환할 이미지 갯수
    class_mode = 'binary' # 라벨링 진행, catergorical : 다중분류
    # 폴더별로 라벨링을 진행 cats(0), dogs(1)
    )
# Out:
# Found 22 images belonging to 2 classes.

# %%
val_generator = val_gen.flow_from_directory(
    val_dir, # train 이미지경로
    target_size = (150, 150), # 변환할 이미지의 크기
    batch_size = 100, # 한번에 변환할 이미지 갯수
    class_mode = 'binary' # 라벨링 진행, catergorical : 다중분류
    # 폴더별로 라벨링을 진행 cats(0), dogs(1)
    )
# Out:
# Found 1000 images belonging to 2 classes.

# %%
# 라벨링 결과 확인
print(train_generator.class_indices)
print(test_generator.class_indices)
print(val_generator.class_indices)
# Out:
# {'cats': 0, 'dogs': 1}
# {'cats': 0, 'dogs': 1}
# {'cats': 0, 'dogs': 1}

# %%
# CNN 모델 설계
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten

# %%
# 딥러닝 모델 생성
model1 = Sequential()

# 입력층, 특징추출부
model1.add(Conv2D(
    filters =32, # 특징의 갯수
    kernel_size = (3,3), # 특징의 크기
    input_shape = (150,150,3), # 입력 데이터의 모양
    padding = 'same', # 입력이미지와 출력이미지의 크기를 동일하게
    activation = 'relu'
))

# 특징이 아니라면 삭제하는 기능
model1.add(MaxPool2D(
    pool_size = (2,2)
))

# 입력층, 특징추출부
model1.add(Conv2D(
    filters =64, # 특징의 갯수
    kernel_size = (3,3), # 특징의 크기
    input_shape = (150,150,3), # 입력 데이터의 모양
    padding = 'same', # 입력이미지와 출력이미지의 크기를 동일하게
    activation = 'relu'
))

# 특징이 아니라면 삭제하는 기능
model1.add(MaxPool2D(
    pool_size = (2,2)
))
############################ 특징 추출부 끝 ###########################
model1.add(Flatten()) # 추출된 특징을 1차원으로 바꿔줌
############################ 분류부 시작 ##########################
# 위에서 특징을 추출했기때문에 층을 깊게 쌓지 않아도됨
model1.add(Dense(units=256, activation='relu'))
model1.add(Dense(units=1, activation='sigmoid'))

# %%
model1.compile(
    loss= 'binary_crossentropy',
    optimizer = 'adam',
    metrics=['accuracy']
)

# %%
model1.fit_generator(
    generator = train_generator, 
    epochs =20,
    validation_data = val_generator
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   after removing the cwd from sys.path.
# Epoch 1/20
# 20/20 [==============================] - 583s 29s/step - loss: 1.4231 - accuracy: 0.5310 - val_loss: 0.6828 - val_accuracy: 0.5470
# Epoch 2/20
# 20/20 [==============================] - 11s 571ms/step - loss: 0.6636 - accuracy: 0.5960 - val_loss: 0.6492 - val_accuracy: 0.6430
# Epoch 3/20
# 20/20 [==============================] - 11s 571ms/step - loss: 0.5862 - accuracy: 0.7320 - val_loss: 0.5898 - val_accuracy: 0.6850
# Epoch 4/20
# 20/20 [==============================] - 11s 572ms/step - loss: 0.4732 - accuracy: 0.8005 - val_loss: 0.5699 - val_accuracy: 0.6980
# Epoch 5/20
# 20/20 [==============================] - 11s 573ms/step - loss: 0.3766 - accuracy: 0.8410 - val_loss: 0.5982 - val_accuracy: 0.6910
# Epoch 6/20
# 20/20 [==============================] - 11s 566ms/step - loss: 0.3033 - accuracy: 0.8800 - val_loss: 0.6620 - val_accuracy: 0.6750
# Epoch 7/20
# 20/20 [==============================] - 11s 567ms/step - loss: 0.2149 - accuracy: 0.9185 - val_loss: 0.7297 - val_accuracy: 0.6960
# Epoch 8/20
# 20/20 [==============================] - 11s 561ms/step - loss: 0.1631 - accuracy: 0.9430 - val_loss: 0.7645 - val_accuracy: 0.6830
# Epoch 9/20
# 20/20 [==============================] - 11s 567ms/step - loss: 0.1059 - accuracy: 0.9780 - val_loss: 0.8702 - val_accuracy: 0.6890
# Epoch 10/20
# 20/20 [==============================] - 11s 570ms/step - loss: 0.0607 - accuracy: 0.9880 - val_loss: 0.9189 - val_accuracy: 0.7100
# Epoch 11/20
# 20/20 [==============================] - 11s 562ms/step - loss: 0.0377 - accuracy: 0.9940 - val_loss: 0.9838 - val_accuracy: 0.7000
# Epoch 12/20
# 20/20 [==============================] - 11s 568ms/step - loss: 0.0283 - accuracy: 0.9960 - val_loss: 1.0811 - val_accuracy: 0.7090
# Epoch 13/20
# 20/20 [==============================] - 12s 612ms/step - loss: 0.0236 - accuracy: 0.9990 - val_loss: 1.1352 - val_accuracy: 0.7040
# Epoch 14/20
# 20/20 [==============================] - 11s 564ms/step - loss: 0.0144 - accuracy: 0.9995 - val_loss: 1.1728 - val_accuracy: 0.7030
# Epoch 15/20
# 20/20 [==============================] - 11s 566ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.2239 - val_accuracy: 0.7150
# Epoch 16/20
# 20/20 [==============================] - 11s 566ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.2945 - val_accuracy: 0.6990
# Epoch 17/20
# 20/20 [==============================] - 11s 568ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.3071 - val_accuracy: 0.7140
# Epoch 18/20
# 20/20 [==============================] - 11s 571ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.3717 - val_accuracy: 0.7060
# Epoch 19/20
# 20/20 [==============================] - 11s 566ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.3737 - val_accuracy: 0.7140
# Epoch 20/20
# 20/20 [==============================] - 11s 572ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.3987 - val_accuracy: 0.7120

# %%
# 과대적합이 관찰되었음
# 과대적합을 해결하는 방법
# 학습데이터 증가
# 딥러닝 모델 재설계 > dropout() 
# 학습데이터 augmentation(확장) : 기존의 이미지에 변화를 줘서 이미지 사용

# %%
# 이미지 확장(증식)
train_aug = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 20,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    shear_range = 0.1,
    zoom_range = 0.1,
    horizontal_flip = True,
    fill_mode = 'nearest' # 비어는 부분을 가장 가까이에 있는 값으로 채움
)

train_aug_generator = train_aug.flow_from_directory(
    train_dir,
    target_size = (150,150),
    batch_size = 100,
    class_mode = 'binary'
)
# Out:
# Found 2000 images belonging to 2 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout

# 딥러닝 모델 생성
model1 = Sequential()

# 입력층, 특징추출부
model1.add(Conv2D(
    filters =32, # 특징의 갯수
    kernel_size = (3,3), # 특징의 크기
    input_shape = (150,150,3), # 입력 데이터의 모양
    padding = 'same', # 입력이미지와 출력이미지의 크기를 동일하게
    activation = 'relu'
))

# 특징이 아니라면 삭제하는 기능
model1.add(MaxPool2D(
    pool_size = (2,2)
))

# 입력층, 특징추출부
model1.add(Conv2D(
    filters =64, # 특징의 갯수
    kernel_size = (3,3), # 특징의 크기
    input_shape = (150,150,3), # 입력 데이터의 모양
    padding = 'same', # 입력이미지와 출력이미지의 크기를 동일하게
    activation = 'relu'
))

# 특징이 아니라면 삭제하는 기능
model1.add(MaxPool2D(
    pool_size = (2,2)
))
############################ 특징 추출부 끝 ###########################
model1.add(Flatten()) # 추출된 특징을 1차원으로 바꿔줌
############################ 분류부 시작 ##########################
# 위에서 특징을 추출했기때문에 층을 깊게 쌓지 않아도됨
model1.add(Dense(units=256, activation='relu'))
model1.add(Dropout(0.4))


# 출력층
model1.add(Dense(units=1, activation='sigmoid'))

# %%
model1.compile(
    loss= 'binary_crossentropy',
    optimizer = 'adam',
    metrics=['accuracy']
)

# %%
model1.fit_generator(
    generator = train_aug_generator, 
    epochs =20,
    validation_data = val_generator
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   after removing the cwd from sys.path.
# Epoch 1/20
# 20/20 [==============================] - 20s 997ms/step - loss: 0.6475 - accuracy: 0.6850 - val_loss: 0.5954 - val_accuracy: 0.6720
# Epoch 2/20
# 20/20 [==============================] - 20s 1s/step - loss: 0.5884 - accuracy: 0.6830 - val_loss: 0.5898 - val_accuracy: 0.6860
# Epoch 3/20
# 20/20 [==============================] - 21s 1s/step - loss: 0.5726 - accuracy: 0.7020 - val_loss: 0.6185 - val_accuracy: 0.6740
# Epoch 4/20
# 20/20 [==============================] - 20s 1s/step - loss: 0.5811 - accuracy: 0.7050 - val_loss: 0.5667 - val_accuracy: 0.6970
# Epoch 5/20
# 20/20 [==============================] - 20s 1s/step - loss: 0.5596 - accuracy: 0.7000 - val_loss: 0.5523 - val_accuracy: 0.7290
# Epoch 6/20
# 20/20 [==============================] - 20s 994ms/step - loss: 0.5497 - accuracy: 0.7260 - val_loss: 0.5560 - val_accuracy: 0.7180
# Epoch 7/20
# 20/20 [==============================] - 20s 994ms/step - loss: 0.5285 - accuracy: 0.7370 - val_loss: 0.5356 - val_accuracy: 0.7310
# Epoch 8/20
# 20/20 [==============================] - 20s 998ms/step - loss: 0.5127 - accuracy: 0.7500 - val_loss: 0.5194 - val_accuracy: 0.7490
# Epoch 9/20
# 20/20 [==============================] - 20s 995ms/step - loss: 0.5224 - accuracy: 0.7390 - val_loss: 0.5186 - val_accuracy: 0.7360
# Epoch 10/20
# 20/20 [==============================] - 20s 991ms/step - loss: 0.5068 - accuracy: 0.7595 - val_loss: 0.5081 - val_accuracy: 0.7400
# Epoch 11/20
# 20/20 [==============================] - 20s 1s/step - loss: 0.5129 - accuracy: 0.7440 - val_loss: 0.5503 - val_accuracy: 0.7150
# Epoch 12/20
# 20/20 [==============================] - 21s 1s/step - loss: 0.5156 - accuracy: 0.7475 - val_loss: 0.5951 - val_accuracy: 0.7060
# Epoch 13/20
# 20/20 [==============================] - 20s 994ms/step - loss: 0.5005 - accuracy: 0.7530 - val_loss: 0.5035 - val_accuracy: 0.7440
# Epoch 14/20
# 20/20 [==============================] - 20s 998ms/step - loss: 0.4930 - accuracy: 0.7540 - val_loss: 0.5586 - val_accuracy: 0.7170
# Epoch 15/20
# 20/20 [==============================] - 20s 997ms/step - loss: 0.4850 - accuracy: 0.7635 - val_loss: 0.5093 - val_accuracy: 0.7470
# Epoch 16/20
# 20/20 [==============================] - 20s 994ms/step - loss: 0.5027 - accuracy: 0.7450 - val_loss: 0.5069 - val_accuracy: 0.7530
# Epoch 17/20
# 20/20 [==============================] - 20s 997ms/step - loss: 0.4886 - accuracy: 0.7695 - val_loss: 0.5249 - val_accuracy: 0.7380
# Epoch 18/20
# 20/20 [==============================] - 20s 1s/step - loss: 0.4977 - accuracy: 0.7575 - val_loss: 0.5045 - val_accuracy: 0.7410
# Epoch 19/20
# 20/20 [==============================] - 20s 989ms/step - loss: 0.4756 - accuracy: 0.7690 - val_loss: 0.5080 - val_accuracy: 0.7530
# Epoch 20/20
# 20/20 [==============================] - 20s 990ms/step - loss: 0.4593 - accuracy: 0.7775 - val_loss: 0.4896 - val_accuracy: 0.7520

# %%
# 전이학습
# 누군가가 만들어 놓은 모델 가져오기
from tensorflow.keras.applications import VGG16

conv_base = VGG16(
    weights = "imagenet", # imagenet에서 사용한 가중치 가져오기 
    include_top = False, # 분류기를 사용할 것 인가?
    input_shape = (150, 150 ,3)
)

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 동결
# 가중치가 갱신되는 것을 막는건

# 학습 가능한 가중치의 갯수 확인
len(conv_base.trainable_weights)
# Out:
# 26

# %%
#  VGG16 전체 층의 대해 동결
conv_base.trainable = False

# %%
len(conv_base.trainable_weights)
# Out:
# 0

# %%
# 동결된 conv를 사용해서 모델 설계
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

model2 = Sequential()

model2.add(conv_base) # 전이학습할 모델의 특성추출부 사용하기

model2.add(Flatten()) 

model2.add(Dense(units=256, activation='relu'))

# 출력층
model2.add(Dense(units=1, activation='sigmoid'))

model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 16,812,353
# Trainable params: 2,097,665
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model2.compile(loss='binary_crossentropy',
               optimizer = 'adam',
               metrics=['accuracy']
               )

# %%
model2.fit_generator(generator= train_aug_generator,
                     epochs=20,
                     validation_data = val_generator)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Epoch 1/20
# 20/20 [==============================] - 1022s 53s/step - loss: 1.0309 - accuracy: 0.5805 - val_loss: 0.5280 - val_accuracy: 0.7160
# Epoch 2/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.4298 - accuracy: 0.8230 - val_loss: 0.3314 - val_accuracy: 0.8740
# Epoch 3/20
# 20/20 [==============================] - 23s 1s/step - loss: 0.3332 - accuracy: 0.8720 - val_loss: 0.2779 - val_accuracy: 0.8930
# Epoch 4/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.2883 - accuracy: 0.8865 - val_loss: 0.2554 - val_accuracy: 0.8990
# Epoch 5/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.2697 - accuracy: 0.8820 - val_loss: 0.2633 - val_accuracy: 0.8910
# Epoch 6/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.2519 - accuracy: 0.8940 - val_loss: 0.2667 - val_accuracy: 0.8900
# Epoch 7/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.2434 - accuracy: 0.8970 - val_loss: 0.2360 - val_accuracy: 0.9060
# Epoch 8/20
# 20/20 [==============================] - 21s 1s/step - loss: 0.2273 - accuracy: 0.9095 - val_loss: 0.2288 - val_accuracy: 0.9090
# Epoch 9/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.2102 - accuracy: 0.9120 - val_loss: 0.2264 - val_accuracy: 0.9110
# Epoch 10/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.2138 - accuracy: 0.9195 - val_loss: 0.2306 - val_accuracy: 0.9120
# Epoch 11/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.1970 - accuracy: 0.9200 - val_loss: 0.2467 - val_accuracy: 0.8930
# Epoch 12/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.2016 - accuracy: 0.9195 - val_loss: 0.2339 - val_accuracy: 0.9070
# Epoch 13/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.1837 - accuracy: 0.9220 - val_loss: 0.2391 - val_accuracy: 0.9070
# Epoch 14/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.1861 - accuracy: 0.9265 - val_loss: 0.2524 - val_accuracy: 0.8970
# Epoch 15/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.1761 - accuracy: 0.9245 - val_loss: 0.2495 - val_accuracy: 0.8980
# Epoch 16/20
# 20/20 [==============================] - 21s 1s/step - loss: 0.1689 - accuracy: 0.9365 - val_loss: 0.2499 - val_accuracy: 0.8990
# Epoch 17/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.1705 - accuracy: 0.9300 - val_loss: 0.2451 - val_accuracy: 0.9060
# Epoch 18/20
# 20/20 [==============================] - 23s 1s/step - loss: 0.1663 - accuracy: 0.9370 - val_loss: 0.2470 - val_accuracy: 0.9080
# Epoch 19/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.1807 - accuracy: 0.9245 - val_loss: 0.2459 - val_accuracy: 0.9060
# Epoch 20/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.1648 - accuracy: 0.9355 - val_loss: 0.2520 - val_accuracy: 0.9040

# %%
# 미세조정방식

# %%
# model2에서 학습가능한 가중치의 갯수
len(model2.trainable_weights)
# Out:
# 30

# %%
conv_base.summary()

# %%
# 전이학습
# 누군가가 만들어 놓은 모델 가져오기
from tensorflow.keras.applications import VGG16

conv_base = VGG16(
    weights = "imagenet", # imagenet에서 사용한 가중치 가져오기 
    include_top = False, # 분류기를 사용할 것 인가?
    input_shape = (150, 150 ,3)
)

# %%
# block5_conv1 ~ 3 층을 학습시켜보자

#block_conv1 층부터 하위의 층의 동결을 해제
set_trainable = False
for layer in conv_base.layers:
  if layer.name == 'block5_conv1':
    set_trainable = True

  if set_trainable == True:
    layer.trainable = True
  else:
    layer.trainable = False

# %%
# 동결된 conv를 사용해서 모델 설계
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
model2 = Sequential()
model2.add(conv_base) # 전이학습할 모델의 특성추출부 사용하기
model2.add(Flatten()) 
model2.add(Dense(units=256, activation='relu'))
model2.add(Dense(units=1, activation='sigmoid'))
model2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_4 (Flatten)         (None, 8192)              0
#
#  dense_8 (Dense)             (None, 256)               2097408
#
#  dense_9 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 16,812,353
# Trainable params: 9,177,089
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
len(model2.trainable_weights)
# Out:
# 10

# %%
model2.compile(loss='binary_crossentropy',
               optimizer = 'adam',
               metrics=['accuracy']
               )

# %%
model2.fit_generator(generator= train_aug_generator,
                     epochs=20,
                     validation_data = val_generator)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Epoch 1/20
# 20/20 [==============================] - 24s 1s/step - loss: 1.1647 - accuracy: 0.5095 - val_loss: 0.6934 - val_accuracy: 0.4990
# Epoch 2/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6963 - accuracy: 0.5020 - val_loss: 0.6936 - val_accuracy: 0.5000
# Epoch 3/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6935 - accuracy: 0.5000 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 4/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6933 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 5/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 6/20
# 20/20 [==============================] - 23s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 7/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 8/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 9/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 10/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 11/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 12/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 13/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 14/20
# 20/20 [==============================] - 23s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.5000
# Epoch 15/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 16/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 17/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 18/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 19/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 20/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
